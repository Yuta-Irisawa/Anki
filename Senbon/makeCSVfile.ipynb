# %%
from google.colab import drive
import os
import csv

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Anki/Senbon')

# %%
with open('readingfile.csv', 'w') as f:
  writer = csv.writer(f)
  for i in range(140):
    writer.writerow(['No.{}'.format(i+1), '<img src="question_{:0=4}.jpg">'.format(i+1), '<img src="answer_{:0=4}.jpg">'.format(2*i+1), '<img src="answer_{:0=4}.jpg">'.format(2*i+2), '[sound:audio_{:0=4}.mp3]'.format(i+1)])
